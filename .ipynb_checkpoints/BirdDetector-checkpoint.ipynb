# %% [markdown]
# *General dependencies*

# %%
#Change it accoprding to your Hardware
#If you have a NVIDIA GPU, read the "install TF and OpenCV with CUDA" section on this notebook
TF_GPU = 1

# %%
#!pip install numpy
#!pip install matplotlib

#We will use virtualenv to create a separate envinment
#!pip install virtualenv

# %%
#Activating the separate environment

#!virtualenv TF_GPU

# %% [markdown]
# **Install TensorFlow and OpenCV with CUDA**
#
# https://thinkinfi.com/conda-install-tensorflow-gpu-jupyter/
#
# OBS: For Python 3.8.X. If you need the last version will be necessary recompile TF or use Linux.
#
# - First: Install CUDA Drivers
#
# TensorFlow and CUDA drivers are directly conected, you need to install the correct version of each one.
# In the link below, you can find a tabble with the TF version and Supported CUDA
# https://www.tensorflow.org/install/source
#
#
# For this project, we will be using TD 2.10, because they are not compiling TF-GPU for Windows after the 2.10 version.
# Dur to this, we will need to install CUDA 11 drivers.
#
# You can download the NVIDIA CUDA drivers from the link:
#
# https://developer.nvidia.com/cuda-11-8-0-download-archive?target_os=Windows&target_arch=x86_64&target_version=11&target_type=exe_local
#
# - Install cuDNN
#
#
#   To have support of Deep Neural Network through CUDA, you need to install cuDNN.
#   cuDNN is compiled for the specific CUDA driver version too, you can download the correct version for you CUDA installation from the link (for CUDA 11 in our case):
#
#   https://developer.nvidia.com/rdp/cudnn-archive
#
#
#   After, extract the files, and copy each dll and .h from its folder to the same folder in CUDA Driver Directory installation.
#
#   For example:
#       Copy all "lib\x64\*.dll" to "C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.8\lib"
#
#
#       Do it for the include and lib files too.
#
#   Now, you are prepared to install TensorFlow GPU.
#
# - Install TensorFlow-GPU
#
#   TF-gpu is only disponible in its 2.10 verion of Windows, that is only compatible with Python 3.7-3.9.
#
#   !pip install tensorflow-gpu==2.10
#
# - OpenCV Cuda
#
#     https://medium.com/analytics-vidhya/build-opencv-from-source-with-cuda-for-gpu-access-on-windows-5cd0ce2b9b37
#
#   Download CMake: https://cmake.org/download/
#
#   Download OpenCV Source Code: https://opencv.org/releases/
#
#   Install CMake
#
#   Extract OpenCD SRC in a folder
#
#   Create "build" directory
#
#   Open the OpenCVDetectPython.cmake into "cmake" dir and

# %%
default_resolution = 224

# %% [markdown]
# def normalize(input):
#     normalized_input = input / 255.0
#     return normalized_input.astype(np.float16)

# %%
def resize(image):
    # Define the desired width and height
    desired_width, desired_height = 224, 224

    # Get the dimensions of the original image
    height, width = image.shape[:2]

    # Calculate the resizing ratio
    width_ratio = desired_width / width
    height_ratio = desired_height / height

    # Choose the minimum ratio to ensure the image fits within the new size
    ratio = min(width_ratio, height_ratio)

    # Calculate the new dimensions of the image
    new_width = int(width * ratio)
    new_height = int(height * ratio)

    # Resize the image to the new dimensions
    resized_image = cv2.resize(image, (new_width, new_height))

    # Create a blank image with the desired size and random background colors (noise)
    background_noise = np.random.randint(0, 256, (desired_height, desired_width, 3), dtype=np.uint8)

    # Calculate the starting coordinates to paste the resized image in the center
    x_start = (desired_width - new_width) // 2
    y_start = (desired_height - new_height) // 2

    # Paste the resized image in the center of the noisy background
    background_noise[y_start:y_start + new_height, x_start:x_start + new_width] = resized_image

    return background_noise

# %%
try:
    import tensorflow as tf
except ImportError:
    #Installing TensorFlow GPU 2.10 to use CUDA 11
    if TF_GPU:
        # !pip install tensorflow-gpu==2.10
    else:
        # !pip install tensorflow

    import tensorflow as tf
    from tensorflow import keras

from tensorflow import keras
from tensorflow.keras import mixed_precision

# %%
#Importing tensorflow and keras API
#from tensorflow import keras

# Importing numpy and pyplot
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2
import pandas as pd
from itertools import islice
#import cv2  # ou from PIL import Image

# %%
print("ensorFlow Version:", tf.__version__)    #Checking TensorFlow version
print("CUDA support:", tf.test.is_built_with_cuda())  #Checking CUDA support
print("GPU:", tf.config.list_physical_devices('GPU')) #Checking available GPUs
print("---------------------------------------------")
print("OpenCV Version:", cv2.__version__) 
print("CUDA support:",cv2.cuda.getCudaEnabledDeviceCount())
# Out:
# ensorFlow Version: 2.10.0
# CUDA support: True
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ---------------------------------------------
# OpenCV Version: 4.8.0
# CUDA support: 1

# %%
import sys
print(sys.executable)
# Out:
# D:\Program Files\Python38\python.exe

# %%
#Loading the CSV file
df = pd.read_csv('../BirdsDataset/birds.csv')

#from https://www.birdlist.org/nam/canada/saskatchewan/saskatchewan.htm
sk_species = pd.read_csv('SK_species.csv')

# %%
#Checking the first 4 lines
df.head(4)
# Out:
#    class id                      filepaths           labels data set  \
# 0         0  train/ABBOTTS BABBLER/001.jpg  ABBOTTS BABBLER    train
# 1         0  train/ABBOTTS BABBLER/007.jpg  ABBOTTS BABBLER    train
# 2         0  train/ABBOTTS BABBLER/008.jpg  ABBOTTS BABBLER    train
# 3         0  train/ABBOTTS BABBLER/009.jpg  ABBOTTS BABBLER    train
#
#         scientific name
# 0  MALACOCINCLA ABBOTTI
# 1  MALACOCINCLA ABBOTTI
# 2  MALACOCINCLA ABBOTTI
# 3  MALACOCINCLA ABBOTTI

# %%
sk_species.head(4)
# Out:
#              scientific name           labels status
# 0              PERDIX PERDIX   GREY PARTRIDGE      R
# 1        PHASIANUS COLCHICUS  COMMON PHEASANT    CRI
# 2            BONASA UMBELLUS    RUFFED GROUSE      O
# 3  CENTROCERCUS UROPHASIANUS      SAGE GROUSE      V

# %%
status_values = ["R", "M", "N", "W", "E"]
filtered_data = sk_species[np.isin(sk_species['status'], status_values)]
print(filtered_data.shape)
filtered_data.head(4)   #Ploting only the species marked as "status_values" status
# Out:
# (161, 3)
#       scientific name                       labels status
# 0       PERDIX PERDIX               GREY PARTRIDGE      R
# 6  OXYURA JAMAICENSIS                   RUDDY DUCK      M
# 8  CYGNUS COLUMBIANUS                  TUNDRA SWAN      M
# 9     ANSER ALBIFRONS  GREATER WHITE-FRONTED GOOSE      M

# %% [markdown]
# - R: Resident, present  year around
# - N: Nests in the area but absent during part of the year
# - M: Migrant, non-breeding. May spend a short period or the entire winter
# - W: Wintering; stays in the area, while its primary nesting range is elsewhere
# - E: National endemic
# National endemic.

# %%
#Filtering SK species on the dataset
filtered_species =  df[np.isin(df['scientific name'], sk_species['scientific name'])]
filtered_species.shape
# Out:
# (16027, 5)

# %%
df=filtered_species

# %%
#classe_names
class_names = df['labels'].unique()
class_names.shape[0]
# Out:
# 92

# %%
len(df)
# Out:
# 16027

# %%
specie_id = 0
for i in range(class_names.shape[0]):
    df.loc[df['labels'] == class_names[i], 'class id'] = specie_id
    #print(class_names[i])
    specie_id+=1

# %%
df
# Out:
#        class id                       filepaths            labels data set  \
# 2422          0  train/AMERICAN BITTERN/001.jpg  AMERICAN BITTERN    train
# 2423          0  train/AMERICAN BITTERN/082.jpg  AMERICAN BITTERN    train
# 2424          0  train/AMERICAN BITTERN/042.jpg  AMERICAN BITTERN    train
# 2425          0  train/AMERICAN BITTERN/004.jpg  AMERICAN BITTERN    train
# 2426          0  train/AMERICAN BITTERN/005.jpg  AMERICAN BITTERN    train
# ...         ...                             ...               ...      ...
# 89840        91       valid/RED CROSSBILL/5.jpg     RED CROSSBILL    valid
# 89841        91       valid/RED CROSSBILL/2.jpg     RED CROSSBILL    valid
# 89842        91       valid/RED CROSSBILL/4.jpg     RED CROSSBILL    valid
# 89843        91       valid/RED CROSSBILL/3.jpg     RED CROSSBILL    valid
# 89844        91       valid/RED CROSSBILL/1.jpg     RED CROSSBILL    valid
#
#              scientific name
# 2422   BOTAURUS LENTIGINOSUS
# 2423   BOTAURUS LENTIGINOSUS
# 2424   BOTAURUS LENTIGINOSUS
# 2425   BOTAURUS LENTIGINOSUS
# 2426   BOTAURUS LENTIGINOSUS
# ...                      ...
# 89840      LOXIA CURVIROSTRA
# 89841      LOXIA CURVIROSTRA
# 89842      LOXIA CURVIROSTRA
# 89843      LOXIA CURVIROSTRA
# 89844      LOXIA CURVIROSTRA
#
# [16027 rows x 5 columns]

# %%
# Creating a mask separation for training and test data
train_mask = df['filepaths'].str.contains('train/')  #Validation and train data will be used as a same dataset during the training
test_mask = df['filepaths'].str.contains('test/|valid/')
#valid_mask = df['filepaths'].str.contains('valid/')

# Applying the mask to separate the datasets
train_data = df[train_mask]
test_data = df[test_mask]
#valid_data = df[valid_mask]

#Visualizing the datasets
print("Train Dataset:")
print(train_data.head())

print("\nTest Dataset:")
print(test_data.head())
# Out:
# Train Dataset:
#       class id                       filepaths            labels data set  \
# 2422         0  train/AMERICAN BITTERN/001.jpg  AMERICAN BITTERN    train
# 2423         0  train/AMERICAN BITTERN/082.jpg  AMERICAN BITTERN    train
# 2424         0  train/AMERICAN BITTERN/042.jpg  AMERICAN BITTERN    train
# 2425         0  train/AMERICAN BITTERN/004.jpg  AMERICAN BITTERN    train
# 2426         0  train/AMERICAN BITTERN/005.jpg  AMERICAN BITTERN    train
#
#             scientific name
# 2422  BOTAURUS LENTIGINOSUS
# 2423  BOTAURUS LENTIGINOSUS
# 2424  BOTAURUS LENTIGINOSUS
# 2425  BOTAURUS LENTIGINOSUS
# 2426  BOTAURUS LENTIGINOSUS
#
# Test Dataset:
#        class id                    filepaths            labels data set  \
# 84710         0  test/AMERICAN BITTERN/1.jpg  AMERICAN BITTERN     test
# 84711         0  test/AMERICAN BITTERN/2.jpg  AMERICAN BITTERN     test
# 84712         0  test/AMERICAN BITTERN/3.jpg  AMERICAN BITTERN     test
# 84713         0  test/AMERICAN BITTERN/4.jpg  AMERICAN BITTERN     test
# 84714         0  test/AMERICAN BITTERN/5.jpg  AMERICAN BITTERN     test
#
#              scientific name
# 84710  BOTAURUS LENTIGINOSUS
# 84711  BOTAURUS LENTIGINOSUS
# 84712  BOTAURUS LENTIGINOSUS
# 84713  BOTAURUS LENTIGINOSUS
# 84714  BOTAURUS LENTIGINOSUS

# %%
#Checking how many images we have in the train dataset
train_data.shape[0]
# Out:
# 15107

# %%
n_images_per_class_to_load = 240 #Change it for the number of images that you would like to load
n_class = class_names.shape[0]   #Chanfe it for the number of classes that you would like to load

# %%
i=0

train_images = []
train_labels = []
for class_id in range(n_class):  # O range inclui até 200
    filtered_images = train_data[train_data['class id'] == class_id]

    n_images_per_class_to_load_int = n_images_per_class_to_load
    if n_images_per_class_to_load_int > len(filtered_images):
        n_images_per_class_to_load_int = len(filtered_images)
    
    for index, row in islice(filtered_images.iterrows(), n_images_per_class_to_load_int):                  
            path='../BirdsDataset/' + row['filepaths']    #Creating the path
            image_path = os.path.join(path)               #Creating the OS Path to the image        
            image = cv2.imread(image_path)
            
            height, width, channels = image.shape   
            if i < len(train_images):                    
                train_images[i] =  resize(image)                
                train_labels[i] = int(row['class id'])
            else:
                train_images.append( resize(image))   
                train_labels.append(int(row['class id']))
            i+=1

# %%
i=0

test_images = []
test_labels = []
for class_id in range(n_class):  # O range inclui até 200
    filtered_images = test_data[test_data['class id'] == class_id]

    n_images_per_class_to_load_int = n_images_per_class_to_load
    if n_images_per_class_to_load_int > len(filtered_images):
        n_images_per_class_to_load_int = len(filtered_images)
    
    for index, row in islice(filtered_images.iterrows(), n_images_per_class_to_load_int):                  
            path='../BirdsDataset/' + row['filepaths']    #Creating the path
            image_path = os.path.join(path)               #Creating the OS Path to the image        
            image = cv2.imread(image_path)
            
            height, width, channels = image.shape    
            if i < len(test_images):
                test_images[i] = resize(image)
                test_labels[i] = int(row['class id'])
            else:
                test_images.append( resize(image))   
                test_labels.append(int(row['class id']))
            i+=1

# %% [raw]
# i=0
#
# valid_images = []
# valid_labels = []
# for class_id in range(n_class):  # O range inclui até 200
#     filtered_images = valid_data[valid_data['class id'] == class_id]
#
#     n_images_per_class_to_load_int = n_images_per_class_to_load
#     if n_images_per_class_to_load_int > len(filtered_images):
#         n_images_per_class_to_load_int = len(filtered_images)
#
#     for index, row in islice(filtered_images.iterrows(), n_images_per_class_to_load_int):
#             path='../BirdsDataset/' + row['filepaths']    #Creating the path
#             image_path = os.path.join(path)               #Creating the OS Path to the image
#             image = cv2.imread(image_path)
#
#             height, width, channels = image.shape
#             if i < len(valid_images):
#                 valid_images[i] =  resize(image)
#                 valid_labels[i] = int(row['class id'])
#             else:
#                 valid_images.append( resize(image))
#                 valid_labels.append(int(row['class id']))
#             i+=1

# %%
#Printing the first 25 images of the train dataset with its classification
#in grid of 5 by 5
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
#Printing the first 25 images of the train dataset with its classification
#in grid of 5 by 5
plt.figure(figsize=(10,10))
for i in range(4):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [raw]
# #Printing the first 25 images of the train dataset with its classification
# #in grid of 5 by 5
# plt.figure(figsize=(10,10))
# for i in range(4):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(valid_images[i], cmap=plt.cm.binary)
#     plt.xlabel(class_names[train_labels[i]])
# plt.show()

# %%
#Reset and clear session
tf.keras.backend.clear_session

#Changing the precision to float16
#It is suficient since we are working with images with 8bits color deph for each channel
#It will reduce the memory amount and reduce the processing time
#policy = mixed_precision.Policy('mixed_float16')
#mixed_precision.set_global_policy(policy)
# Out:
# <function keras.backend.clear_session()>

# %%
#Converting to numpy array
train_images = np.array(train_images)
test_images = np.array(test_images)
#valid_images = np.array(valid_images)

# Converter train_labels para um NumPy array
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)
#valid_labels = np.array(valid_labels)

# %%
#https://www.tensorflow.org/tutorials/images/classification?hl=pt-br
#tf.keras.backend.clear_session()

#model = keras.Sequential([
#  layers.Rescaling(1./255, input_shape=(height, width, channels)),
#  layers.Conv2D(16, 3, padding='same', activation='relu'),
#  layers.MaxPooling2D(),
#  layers.Conv2D(32, 3, padding='same', activation='relu'),
#  layers.MaxPooling2D(),
#  layers.Conv2D(64, 3, padding='same', activation='relu'),
#  layers.MaxPooling2D(),
#  layers.Flatten(),
#  layers.Dense(1000, activation='relu'),
#  layers.Dense(n_class, activation='softmax')
#])

# %%
#base_model = keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(height, width, channels))
# Congele as camadas do modelo base
#for layer in base_model.layers:
#    layer.trainable = False
#
#strategy = tf.distribute.MirroredStrategy()

#with strategy.scope():
#    model = keras.Sequential([
#        #layers.Rescaling(1./255, input_shape=(height, width, channels)),
#        base_model,
#        layers.Flatten(),
#        layers.Dense(1000, activation='relu'),
#        layers.Dense(n_class, activation='softmax')
#])

# %%
# https://www.geeksforgeeks.org/multiclass-image-classification-using-transfer-learning/
# https://pyimagesearch.com/2018/12/31/keras-conv2d-and-convolutional-layers/

from tensorflow.keras.regularizers import l2

#Distribution strategy - This will enable TF to use CPU and GPU
strategy = tf.distribute.MirroredStrategy()

# Defining a function to create our model
def create_model():
    #base_model = keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(height, width, channels))
    base_model = tf.keras.applications.InceptionV3(include_top= False,)
    
    #Freezing the Resnet50 model
    #for layer in base_model.layers:
    #    layer.trainable = False
    base_model.trainable = False

    model = keras.Sequential([
        layers.Rescaling(1./255, input_shape=(224, 224, 3)),            
        base_model,                
   
        layers.Conv2D(920, 3, padding='same', activation='relu'),   #Inception has a last conv layer with +1500 filters. This layer will simplify it to 920
        layers.BatchNormalization(),    
 
        
        layers.MaxPooling2D(name = "max_pooling_layer"),
        #layers.GlobalAveragePooling2D(name = "global_average_pooling_layer"),        
        layers.Flatten(),       
        
        layers.Dense(3312, activation='LeakyReLU'),  #2484  LeakyReLU
        layers.LeakyReLU(alpha=0.1),
        layers.Dropout(0.45),
        
        layers.Dense(1104, activation='LeakyReLU'),  #4
        layers.ELU(alpha=0.1),
        layers.Dropout(0.3),  

        #layers.Dense(920, activation='relu'),  #4
        #layers.Dropout(0.3),         
        
        layers.Dense(368, activation='relu'),  #4        
        layers.Dropout(0.25),   
        
       
        
        layers.Dense(n_class, activation='softmax', kernel_regularizer=l2(0.1))  #kernel_regularizer=l2(0.5)
    ])

    return model

# Creating the model
with strategy.scope():
    model = create_model()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
model.compile(optimizer=tf.keras.optimizers.Adamax(),  
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy']
             )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Data generator for data augmentation
datagen_augmented = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.25,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
#Training Batch size
batch_size = 32

# Batch generator for original images that will be used as validation
datagen_original = ImageDataGenerator()

# Batch generator for the augmented data and original data
generator_augmented = datagen_augmented.flow(train_images, train_labels, batch_size=batch_size, shuffle=True)
generator_original  = datagen_original.flow(train_images, train_labels, batch_size=batch_size, shuffle=True)

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (15107, 224, 224, 3)
# (15107,)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

#fileame and path to save
checkpoint_path = 'checkpoint.h5'

# Creating model checkpoint
model_checkpoint = ModelCheckpoint(
    checkpoint_path,
    monitor='val_accuracy',  # Metric adopted
    save_best_only=True,  # Save only the best model
    mode='max',  # Use max for accuracy and min for loss
    verbose=1  
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# %%
model.fit(
    generator_augmented, 
    #use_multiprocessing=True,
    steps_per_epoch=len(train_images) // batch_size, 
    epochs=60, 
    workers=8,                          #Number of threads
    validation_data=generator_original, #(valid_images, valid_labels)
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/60
# 472/472 [==============================] - ETA: 0s - loss: 8.1514 - accuracy: 0.2157
# Epoch 1: val_accuracy improved from -inf to 0.54961, saving model to checkpoint.h5
# 472/472 [==============================] - 116s 221ms/step - loss: 8.1514 - accuracy: 0.2157 - val_loss: 3.7567 - val_accuracy: 0.5496
# Epoch 2/60
# 472/472 [==============================] - ETA: 0s - loss: 3.3118 - accuracy: 0.4842
# Epoch 2: val_accuracy improved from 0.54961 to 0.69120, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 212ms/step - loss: 3.3118 - accuracy: 0.4842 - val_loss: 2.0241 - val_accuracy: 0.6912
# Epoch 3/60
# 472/472 [==============================] - ETA: 0s - loss: 2.2212 - accuracy: 0.5871
# Epoch 3: val_accuracy improved from 0.69120 to 0.75561, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 213ms/step - loss: 2.2212 - accuracy: 0.5871 - val_loss: 1.3863 - val_accuracy: 0.7556
# Epoch 4/60
# 472/472 [==============================] - ETA: 0s - loss: 1.7478 - accuracy: 0.6379
# Epoch 4: val_accuracy improved from 0.75561 to 0.76256, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 212ms/step - loss: 1.7478 - accuracy: 0.6379 - val_loss: 1.1874 - val_accuracy: 0.7626
# Epoch 5/60
# 472/472 [==============================] - ETA: 0s - loss: 1.4726 - accuracy: 0.6779
# Epoch 5: val_accuracy improved from 0.76256 to 0.80665, saving model to checkpoint.h5
# 472/472 [==============================] - 98s 206ms/step - loss: 1.4726 - accuracy: 0.6779 - val_loss: 0.9431 - val_accuracy: 0.8066
# Epoch 6/60
# 472/472 [==============================] - ETA: 0s - loss: 1.2797 - accuracy: 0.7102
# Epoch 6: val_accuracy improved from 0.80665 to 0.81611, saving model to checkpoint.h5
# 472/472 [==============================] - 98s 207ms/step - loss: 1.2797 - accuracy: 0.7102 - val_loss: 0.8345 - val_accuracy: 0.8161
# Epoch 7/60
# 472/472 [==============================] - ETA: 0s - loss: 1.1727 - accuracy: 0.7264
# Epoch 7: val_accuracy improved from 0.81611 to 0.83418, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 210ms/step - loss: 1.1727 - accuracy: 0.7264 - val_loss: 0.7502 - val_accuracy: 0.8342
# Epoch 8/60
# 472/472 [==============================] - ETA: 0s - loss: 1.0931 - accuracy: 0.7403
# Epoch 8: val_accuracy improved from 0.83418 to 0.85755, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 213ms/step - loss: 1.0931 - accuracy: 0.7403 - val_loss: 0.6560 - val_accuracy: 0.8575
# Epoch 9/60
# 472/472 [==============================] - ETA: 0s - loss: 1.0224 - accuracy: 0.7501
# Epoch 9: val_accuracy did not improve from 0.85755
# 472/472 [==============================] - 97s 204ms/step - loss: 1.0224 - accuracy: 0.7501 - val_loss: 0.6659 - val_accuracy: 0.8401
# Epoch 10/60
# 472/472 [==============================] - ETA: 0s - loss: 0.9692 - accuracy: 0.7616
# Epoch 10: val_accuracy improved from 0.85755 to 0.86311, saving model to checkpoint.h5
# 472/472 [==============================] - 103s 217ms/step - loss: 0.9692 - accuracy: 0.7616 - val_loss: 0.5860 - val_accuracy: 0.8631
# Epoch 11/60
# 472/472 [==============================] - ETA: 0s - loss: 0.9158 - accuracy: 0.7704
# Epoch 11: val_accuracy improved from 0.86311 to 0.86927, saving model to checkpoint.h5
# 472/472 [==============================] - 106s 224ms/step - loss: 0.9158 - accuracy: 0.7704 - val_loss: 0.5461 - val_accuracy: 0.8693
# Epoch 12/60
# 472/472 [==============================] - ETA: 0s - loss: 0.8814 - accuracy: 0.7821
# Epoch 12: val_accuracy improved from 0.86927 to 0.88198, saving model to checkpoint.h5
# 472/472 [==============================] - 117s 246ms/step - loss: 0.8814 - accuracy: 0.7821 - val_loss: 0.4994 - val_accuracy: 0.8820
# Epoch 13/60
# 472/472 [==============================] - ETA: 0s - loss: 0.8504 - accuracy: 0.7907
# Epoch 13: val_accuracy improved from 0.88198 to 0.88416, saving model to checkpoint.h5
# 472/472 [==============================] - 102s 214ms/step - loss: 0.8504 - accuracy: 0.7907 - val_loss: 0.4990 - val_accuracy: 0.8842
# Epoch 14/60
# 472/472 [==============================] - ETA: 0s - loss: 0.8241 - accuracy: 0.7937
# Epoch 14: val_accuracy did not improve from 0.88416
# 472/472 [==============================] - 100s 210ms/step - loss: 0.8241 - accuracy: 0.7937 - val_loss: 0.4918 - val_accuracy: 0.8805
# Epoch 15/60
# 472/472 [==============================] - ETA: 0s - loss: 0.7935 - accuracy: 0.7994
# Epoch 15: val_accuracy improved from 0.88416 to 0.89574, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 214ms/step - loss: 0.7935 - accuracy: 0.7994 - val_loss: 0.4461 - val_accuracy: 0.8957
# Epoch 16/60
# 472/472 [==============================] - ETA: 0s - loss: 0.7698 - accuracy: 0.8074
# Epoch 16: val_accuracy did not improve from 0.89574
# 472/472 [==============================] - 100s 212ms/step - loss: 0.7698 - accuracy: 0.8074 - val_loss: 0.4457 - val_accuracy: 0.8918
# Epoch 17/60
# 472/472 [==============================] - ETA: 0s - loss: 0.7547 - accuracy: 0.8079
# Epoch 17: val_accuracy did not improve from 0.89574
# 472/472 [==============================] - 101s 213ms/step - loss: 0.7547 - accuracy: 0.8079 - val_loss: 0.4390 - val_accuracy: 0.8955
# Epoch 18/60
# 472/472 [==============================] - ETA: 0s - loss: 0.7324 - accuracy: 0.8147
# Epoch 18: val_accuracy improved from 0.89574 to 0.90594, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 213ms/step - loss: 0.7324 - accuracy: 0.8147 - val_loss: 0.3970 - val_accuracy: 0.9059
# Epoch 19/60
# 472/472 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.8198
# Epoch 19: val_accuracy improved from 0.90594 to 0.90885, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 212ms/step - loss: 0.7070 - accuracy: 0.8198 - val_loss: 0.3831 - val_accuracy: 0.9089
# Epoch 20/60
# 472/472 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.8213
# Epoch 20: val_accuracy improved from 0.90885 to 0.91580, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 213ms/step - loss: 0.7055 - accuracy: 0.8213 - val_loss: 0.3558 - val_accuracy: 0.9158
# Epoch 21/60
# 472/472 [==============================] - ETA: 0s - loss: 0.6717 - accuracy: 0.8299
# Epoch 21: val_accuracy did not improve from 0.91580
# 472/472 [==============================] - 98s 207ms/step - loss: 0.6717 - accuracy: 0.8299 - val_loss: 0.3622 - val_accuracy: 0.9108
# Epoch 22/60
# 472/472 [==============================] - ETA: 0s - loss: 0.6673 - accuracy: 0.8328
# Epoch 22: val_accuracy did not improve from 0.91580
# 472/472 [==============================] - 97s 206ms/step - loss: 0.6673 - accuracy: 0.8328 - val_loss: 0.3795 - val_accuracy: 0.9079
# Epoch 23/60
# 472/472 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.8376
# Epoch 23: val_accuracy did not improve from 0.91580
# 472/472 [==============================] - 97s 205ms/step - loss: 0.6400 - accuracy: 0.8376 - val_loss: 0.3627 - val_accuracy: 0.9138
# Epoch 24/60
# 472/472 [==============================] - ETA: 0s - loss: 0.6402 - accuracy: 0.8368
# Epoch 24: val_accuracy improved from 0.91580 to 0.92335, saving model to checkpoint.h5
# 472/472 [==============================] - 102s 214ms/step - loss: 0.6402 - accuracy: 0.8368 - val_loss: 0.3254 - val_accuracy: 0.9233
# Epoch 25/60
# 472/472 [==============================] - ETA: 0s - loss: 0.6153 - accuracy: 0.8398
# Epoch 25: val_accuracy did not improve from 0.92335
# 472/472 [==============================] - 98s 206ms/step - loss: 0.6153 - accuracy: 0.8398 - val_loss: 0.3438 - val_accuracy: 0.9166
# Epoch 26/60
# 472/472 [==============================] - ETA: 0s - loss: 0.6084 - accuracy: 0.8423
# Epoch 26: val_accuracy did not improve from 0.92335
# 472/472 [==============================] - 95s 201ms/step - loss: 0.6084 - accuracy: 0.8423 - val_loss: 0.3341 - val_accuracy: 0.9194
# Epoch 27/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5928 - accuracy: 0.8517
# Epoch 27: val_accuracy improved from 0.92335 to 0.92944, saving model to checkpoint.h5
# 472/472 [==============================] - 98s 207ms/step - loss: 0.5928 - accuracy: 0.8517 - val_loss: 0.3003 - val_accuracy: 0.9294
# Epoch 28/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5935 - accuracy: 0.8507
# Epoch 28: val_accuracy did not improve from 0.92944
# 472/472 [==============================] - 95s 201ms/step - loss: 0.5935 - accuracy: 0.8507 - val_loss: 0.3117 - val_accuracy: 0.9276
# Epoch 29/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5808 - accuracy: 0.8529
# Epoch 29: val_accuracy improved from 0.92944 to 0.93242, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 210ms/step - loss: 0.5808 - accuracy: 0.8529 - val_loss: 0.2929 - val_accuracy: 0.9324
# Epoch 30/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5630 - accuracy: 0.8583
# Epoch 30: val_accuracy improved from 0.93242 to 0.93248, saving model to checkpoint.h5
# 472/472 [==============================] - 99s 210ms/step - loss: 0.5630 - accuracy: 0.8583 - val_loss: 0.2904 - val_accuracy: 0.9325
# Epoch 31/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5779 - accuracy: 0.8541
# Epoch 31: val_accuracy improved from 0.93248 to 0.93480, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 211ms/step - loss: 0.5779 - accuracy: 0.8541 - val_loss: 0.2815 - val_accuracy: 0.9348
# Epoch 32/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5477 - accuracy: 0.8637
# Epoch 32: val_accuracy improved from 0.93480 to 0.93811, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 211ms/step - loss: 0.5477 - accuracy: 0.8637 - val_loss: 0.2740 - val_accuracy: 0.9381
# Epoch 33/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5571 - accuracy: 0.8600
# Epoch 33: val_accuracy did not improve from 0.93811
# 472/472 [==============================] - 98s 207ms/step - loss: 0.5571 - accuracy: 0.8600 - val_loss: 0.2795 - val_accuracy: 0.9369
# Epoch 34/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5497 - accuracy: 0.8640
# Epoch 34: val_accuracy improved from 0.93811 to 0.94234, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 211ms/step - loss: 0.5497 - accuracy: 0.8640 - val_loss: 0.2615 - val_accuracy: 0.9423
# Epoch 35/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5163 - accuracy: 0.8707
# Epoch 35: val_accuracy did not improve from 0.94234
# 472/472 [==============================] - 98s 207ms/step - loss: 0.5163 - accuracy: 0.8707 - val_loss: 0.2642 - val_accuracy: 0.9394
# Epoch 36/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5245 - accuracy: 0.8653
# Epoch 36: val_accuracy improved from 0.94234 to 0.94327, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 213ms/step - loss: 0.5245 - accuracy: 0.8653 - val_loss: 0.2555 - val_accuracy: 0.9433
# Epoch 37/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.8669
# Epoch 37: val_accuracy did not improve from 0.94327
# 472/472 [==============================] - 98s 207ms/step - loss: 0.5232 - accuracy: 0.8669 - val_loss: 0.2581 - val_accuracy: 0.9421
# Epoch 38/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5182 - accuracy: 0.8682
# Epoch 38: val_accuracy improved from 0.94327 to 0.94460, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 212ms/step - loss: 0.5182 - accuracy: 0.8682 - val_loss: 0.2456 - val_accuracy: 0.9446
# Epoch 39/60
# 472/472 [==============================] - ETA: 0s - loss: 0.5081 - accuracy: 0.8726
# Epoch 39: val_accuracy did not improve from 0.94460
# 472/472 [==============================] - 98s 206ms/step - loss: 0.5081 - accuracy: 0.8726 - val_loss: 0.2703 - val_accuracy: 0.9393
# Epoch 40/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4946 - accuracy: 0.8798
# Epoch 40: val_accuracy improved from 0.94460 to 0.94691, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 210ms/step - loss: 0.4946 - accuracy: 0.8798 - val_loss: 0.2377 - val_accuracy: 0.9469
# Epoch 41/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4797 - accuracy: 0.8821
# Epoch 41: val_accuracy did not improve from 0.94691
# 472/472 [==============================] - 96s 203ms/step - loss: 0.4797 - accuracy: 0.8821 - val_loss: 0.2493 - val_accuracy: 0.9440
# Epoch 42/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4963 - accuracy: 0.8766
# Epoch 42: val_accuracy improved from 0.94691 to 0.95155, saving model to checkpoint.h5
# 472/472 [==============================] - 98s 207ms/step - loss: 0.4963 - accuracy: 0.8766 - val_loss: 0.2215 - val_accuracy: 0.9515
# Epoch 43/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.8788
# Epoch 43: val_accuracy did not improve from 0.95155
# 472/472 [==============================] - 96s 203ms/step - loss: 0.4818 - accuracy: 0.8788 - val_loss: 0.2367 - val_accuracy: 0.9479
# Epoch 44/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.8833
# Epoch 44: val_accuracy improved from 0.95155 to 0.95227, saving model to checkpoint.h5
# 472/472 [==============================] - 99s 208ms/step - loss: 0.4710 - accuracy: 0.8833 - val_loss: 0.2140 - val_accuracy: 0.9523
# Epoch 45/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.8837
# Epoch 45: val_accuracy did not improve from 0.95227
# 472/472 [==============================] - 97s 205ms/step - loss: 0.4615 - accuracy: 0.8837 - val_loss: 0.2364 - val_accuracy: 0.9459
# Epoch 46/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4576 - accuracy: 0.8867
# Epoch 46: val_accuracy improved from 0.95227 to 0.95466, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 213ms/step - loss: 0.4576 - accuracy: 0.8867 - val_loss: 0.2184 - val_accuracy: 0.9547
# Epoch 47/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.8864
# Epoch 47: val_accuracy did not improve from 0.95466
# 472/472 [==============================] - 98s 207ms/step - loss: 0.4545 - accuracy: 0.8864 - val_loss: 0.2237 - val_accuracy: 0.9487
# Epoch 48/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4485 - accuracy: 0.8899
# Epoch 48: val_accuracy improved from 0.95466 to 0.95797, saving model to checkpoint.h5
# 472/472 [==============================] - 101s 212ms/step - loss: 0.4485 - accuracy: 0.8899 - val_loss: 0.2041 - val_accuracy: 0.9580
# Epoch 49/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4480 - accuracy: 0.8868
# Epoch 49: val_accuracy did not improve from 0.95797
# 472/472 [==============================] - 98s 207ms/step - loss: 0.4480 - accuracy: 0.8868 - val_loss: 0.2289 - val_accuracy: 0.9476
# Epoch 50/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4435 - accuracy: 0.8912
# Epoch 50: val_accuracy did not improve from 0.95797
# 472/472 [==============================] - 98s 206ms/step - loss: 0.4435 - accuracy: 0.8912 - val_loss: 0.2093 - val_accuracy: 0.9547
# Epoch 51/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4327 - accuracy: 0.8903
# Epoch 51: val_accuracy improved from 0.95797 to 0.95922, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 212ms/step - loss: 0.4327 - accuracy: 0.8903 - val_loss: 0.1963 - val_accuracy: 0.9592
# Epoch 52/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.8933
# Epoch 52: val_accuracy did not improve from 0.95922
# 472/472 [==============================] - 98s 206ms/step - loss: 0.4443 - accuracy: 0.8933 - val_loss: 0.2129 - val_accuracy: 0.9533
# Epoch 53/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.8937
# Epoch 53: val_accuracy improved from 0.95922 to 0.96207, saving model to checkpoint.h5
# 472/472 [==============================] - 100s 211ms/step - loss: 0.4296 - accuracy: 0.8937 - val_loss: 0.1854 - val_accuracy: 0.9621
# Epoch 54/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8989
# Epoch 54: val_accuracy improved from 0.96207 to 0.96551, saving model to checkpoint.h5
# 472/472 [==============================] - 102s 214ms/step - loss: 0.4105 - accuracy: 0.8989 - val_loss: 0.1711 - val_accuracy: 0.9655
# Epoch 55/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4124 - accuracy: 0.8962
# Epoch 55: val_accuracy did not improve from 0.96551
# 472/472 [==============================] - 97s 203ms/step - loss: 0.4124 - accuracy: 0.8962 - val_loss: 0.1873 - val_accuracy: 0.9617
# Epoch 56/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4176 - accuracy: 0.8982
# Epoch 56: val_accuracy did not improve from 0.96551
# 472/472 [==============================] - 96s 203ms/step - loss: 0.4176 - accuracy: 0.8982 - val_loss: 0.1860 - val_accuracy: 0.9605
# Epoch 57/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8978
# Epoch 57: val_accuracy did not improve from 0.96551
# 472/472 [==============================] - 97s 204ms/step - loss: 0.4160 - accuracy: 0.8978 - val_loss: 0.1869 - val_accuracy: 0.9594
# Epoch 58/60
# 472/472 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.8988
# Epoch 58: val_accuracy did not improve from 0.96551
# 472/472 [==============================] - 98s 206ms/step - loss: 0.4094 - accuracy: 0.8988 - val_loss: 0.1815 - val_accuracy: 0.9624
# Epoch 59/60
# 472/472 [==============================] - ETA: 0s - loss: 0.3911 - accuracy: 0.9030
# Epoch 59: val_accuracy did not improve from 0.96551
# 472/472 [==============================] - 98s 207ms/step - loss: 0.3911 - accuracy: 0.9030 - val_loss: 0.1804 - val_accuracy: 0.9607

# %% [raw]
# #Training the model with 10 iterations. More iteration may increase the accuracy]
# batch_size = 32
#
# model.fit(
#     train_images,
#     train_labels,
#     shuffle = True,
#     use_multiprocessing=True,
#     batch_size=batch_size,
#     steps_per_epoch=len(train_images) // batch_size ,
#     epochs=10,
#     validation_data=(valid_images, valid_labels)
# )

# %%
from tensorflow.keras.models import load_model

# Carregue o modelo a partir do arquivo de checkpoint
model_checkpoint = load_model('checkpoint.h5')

test_loss, test_acc_checkpoint = model_checkpoint.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 29/29 - 6s - loss: 0.3480 - accuracy: 0.9207 - 6s/epoch - 200ms/step

# %%
#Here, we can verify the accuracy of the trained model
#from keras.models import load_model
#model = load_model('AIBirdDetector_150.h5')
#model = load_model('AIBirdDetector_sk.h5')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 29/29 - 3s - loss: 0.3480 - accuracy: 0.9207 - 3s/epoch - 90ms/step

# %%
print('\nCheckpoint accuracy:', test_acc_checkpoint)
print('Model accuracy:', test_acc)

if test_acc < test_acc_checkpoint:
    print('\nTest accuracy from Checkpoint is better:', test_acc_checkpoint)
else:
    print('\nTest accuracy from end model is better:', test_acc)


#model = model_checkpoint;
#test_acc = test_acc_checkpoint
# Out:
# Checkpoint accuracy: 0.9206521511077881
# Model accuracy: 0.9206521511077881
#
# Test accuracy from end model is better: 0.9206521511077881

# %%
#Checking the accuracy for each class to verify what is the worst
#Using this list, it's possible to understand what class needs to be reinforced with more/new images
#model = load_model('AIBirdDetector_sk.h5')

global_acc=test_acc
worst_images_classes = []
worst_labels_classes = []

z=0
wc = 0
acc = 0
for cls in  class_names:    
    test_images_classes = []
    test_labels_classes = []
    for i in range(len(test_labels)):        
        if class_names[test_labels[i]] == cls:
            if len(test_images) == 1:
                test_images_classes[0] = test_images[i]
                test_labels_classes[0] = test_labels[i]
            else:
                test_images_classes.append(test_images[i])
                test_labels_classes.append(test_labels[i])

    
    test_images_classes = np.array(test_images_classes)
    test_labels_classes = np.array(test_labels_classes)
    #print(test_labels_classes)
    test_acc = 0;
    test_loss, test_acc = model.evaluate(test_images_classes,  test_labels_classes, verbose=0)
    if test_acc < 0.89:
        print(str(cls) + ': ' + str(test_acc))  
        wc+=1

        #Catalog of the worst classes to train again
        for y in range(len(test_images_classes)):
            if len(test_images) == 1:            
                worst_images_classes[0] = test_images_classes[y]
                worst_labels_classes[0] = test_labels_classes[y]
            else:
                worst_images_classes.append(test_images_classes[y])
                worst_labels_classes.append(test_labels_classes[y])
        
    else:
        acc += test_acc
        z+=1
print('\nNumber of worst classes: ' +str(wc))
print('\nTotal Accuracy: ' + str(global_acc))
print('Accuracy without worst classes: ' + str(acc/z))
# Out:
# BREWERS BLACKBIRD: 0.4000000059604645
# BROWN HEADED COWBIRD: 0.699999988079071
# CANVASBACK: 0.800000011920929
# GILDED FLICKER: 0.4000000059604645
# HOUSE SPARROW: 0.699999988079071
# JACOBIN PIGEON: 0.800000011920929
# LOGGERHEAD SHRIKE: 0.800000011920929
# RED HEADED DUCK: 0.800000011920929
# RED TAILED HAWK: 0.6000000238418579
# RED WINGED BLACKBIRD: 0.699999988079071
# SANDHILL CRANE: 0.800000011920929
# SAYS PHOEBE: 0.6000000238418579
# SNOW GOOSE: 0.800000011920929
# VEERY: 0.5
# YELLOW BREASTED CHAT: 0.800000011920929
# RED CROSSBILL: 0.6000000238418579
#
# Number of worst classes: 16
#
# Total Accuracy: 0.9206521511077881
# Accuracy without worst classes: 0.9723684144647498

# %%
worst_images_classes = np.array(worst_images_classes)        
worst_labels_classes = np.array(worst_labels_classes)
print(worst_images_classes.shape)
print(worst_labels_classes.shape)
# Out:
# (160, 224, 224, 3)
# (160,)

# %% [raw]
# #Training the model with 10 iterations. More iteration may increase the accuracy]
# if len(worst_labels_classes) > 0:
#     batch_size = 32
#
#     model.fit(
#         worst_images_classes,
#         worst_labels_classes,
#         shuffle = True,
#         use_multiprocessing=True,
#         batch_size=batch_size,
#         steps_per_epoch=len(worst_images_classes) // batch_size ,
#         epochs=10
#         #validation_data=(test_images, test_labels)
#     )

# %% [raw]
# print(model.summary())

# %%
model.save('AIBirdDetector_sk.h5')

# %%
#Making some predctions based on the "test images" dataset
predictions = model.predict(test_images)
# Out:
# 29/29 [==============================] - 4s 89ms/step

# %%
#Prediction will return an array with 100 positions, where each position is one class.
predictions[10]
# Out:
# array([2.87848909e-08, 9.99965191e-01, 5.88277777e-12, 4.00369127e-10,
#        9.24168381e-11, 2.81035972e-09, 1.19398280e-07, 9.11704393e-11,
#        1.01620913e-10, 3.88387456e-09, 7.52003348e-10, 5.42912267e-06,
#        6.18730134e-09, 1.30788089e-06, 4.51071225e-09, 2.12255057e-11,
#        1.29364921e-07, 4.07065735e-11, 4.99398689e-10, 1.74476475e-10,
#        1.32781381e-07, 8.40185965e-09, 1.04055093e-08, 1.62973399e-10,
#        5.39144118e-10, 1.25061504e-07, 1.45420256e-06, 8.09617859e-11,
#        3.81287051e-11, 5.84809146e-10, 1.57837743e-08, 1.24386247e-07,
#        5.75076609e-09, 1.70538883e-09, 6.24399907e-11, 3.02748870e-09,
#        5.67229907e-09, 1.41722007e-11, 1.11414822e-09, 3.65209196e-09,
#        1.38509160e-09, 2.56321409e-09, 9.80331705e-10, 1.29724408e-11,
#        2.14829354e-09, 3.51168694e-09, 9.73967781e-12, 4.91022035e-07,
#        1.06420683e-09, 1.95435068e-09, 8.38725622e-09, 1.30532798e-11,
#        1.30813013e-10, 1.17301809e-07, 8.76901718e-10, 3.97207423e-09,
#        3.06014059e-08, 5.68043459e-11, 1.97257446e-08, 5.73142822e-09,
#        1.13780130e-09, 2.91019570e-10, 3.12095766e-10, 6.11971203e-08,
#        6.94671126e-11, 9.80494352e-10, 3.37617601e-10, 9.34504474e-10,
#        1.19866774e-08, 1.86798808e-08, 1.06184683e-09, 5.77360937e-11,
#        9.36752258e-08, 6.15941875e-09, 5.37118808e-07, 6.42066482e-07,
#        1.58287461e-09, 1.81319535e-07, 2.44442755e-09, 1.28028958e-07,
#        4.30120872e-06, 1.38385321e-05, 2.36958980e-10, 1.31176250e-07,
#        3.71890607e-09, 5.30820944e-06, 1.10682116e-10, 1.67636308e-10,
#        3.26595390e-10, 3.73618434e-08, 9.92506410e-10, 1.70590706e-08],
#       dtype=float32)

# %%
##### Checking the predction
np.argmax(predictions[10])
# Out:
# 1

# %%
#We can also use it as the index of our class_names array and return the class...
class_names[np.argmax(predictions[10])]
# Out:
# 'AMERICAN COOT'

# %% [raw]
# ##### plt.figure()
# plt.imshow(int(test_images[10]*255))
# plt.colorbar()
# plt.grid(False)
# plt.show()

# %%
class_names[test_labels[52]]
# Out:
# 'AMERICAN ROBIN'

# %%
class_names[17]
# Out:
# 'BROWN CREPPER'

# %%
pd.DataFrame(class_names).to_csv('class_names.csv')

# %%
for i in range(len(class_names)):
    print(class_names[i])
# Out:
# AMERICAN BITTERN
# AMERICAN COOT
# AMERICAN KESTREL
# AMERICAN PIPIT
# AMERICAN REDSTART
# AMERICAN ROBIN
# BALD EAGLE
# BALTIMORE ORIOLE
# BARN SWALLOW
# BARROWS GOLDENEYE
# BELTED KINGFISHER
# BLACK NECKED STILT
# BLACK-CAPPED CHICKADEE
# BLACK-NECKED GREBE
# BLUE HERON
# BOBOLINK
# BREWERS BLACKBIRD
# BROWN CREPPER
# BROWN HEADED COWBIRD
# BROWN THRASHER
# BUFFLEHEAD
# CALIFORNIA GULL
# CANVASBACK
# CEDAR WAXWING
# CHIPPING SPARROW
# CINNAMON TEAL
# CLARKS GREBE
# COMMON GRACKLE
# COMMON LOON
# COMMON STARLING
# CRESTED NUTHATCH
# DARK EYED JUNCO
# DOUBLE BRESTED CORMARANT
# DOWNY WOODPECKER
# EASTERN BLUEBIRD
# EASTERN TOWEE
# EURASIAN MAGPIE
# GILDED FLICKER
# GOLDEN EAGLE
# GRAY CATBIRD
# GRAY PARTRIDGE
# GREATOR SAGE GROUSE
# GREY PLOVER
# GYRFALCON
# HARLEQUIN DUCK
# HOODED MERGANSER
# HORNED LARK
# HOUSE SPARROW
# JACOBIN PIGEON
# KILLDEAR
# LARK BUNTING
# LAZULI BUNTING
# LOGGERHEAD SHRIKE
# LONG-EARED OWL
# MALLARD DUCK
# MERLIN
# MOURNING DOVE
# NORTHERN FLICKER
# NORTHERN GOSHAWK
# OSPREY
# PAINTED BUNTING
# PEREGRINE FALCON
# PURPLE MARTIN
# RED HEADED DUCK
# RED HEADED WOODPECKER
# RED KNOT
# RED TAILED HAWK
# RED WINGED BLACKBIRD
# RING-NECKED PHEASANT
# ROCK DOVE
# ROSE BREASTED GROSBEAK
# ROUGH LEG BUZZARD
# RUBY CROWNED KINGLET
# RUBY THROATED HUMMINGBIRD
# SAND MARTIN
# SANDHILL CRANE
# SAYS PHOEBE
# SHORT BILLED DOWITCHER
# SMITHS LONGSPUR
# SNOW GOOSE
# SORA
# SURF SCOTER
# TEAL DUCK
# TREE SWALLOW
# TRUMPTER SWAN
# TURKEY VULTURE
# VEERY
# WHIMBREL
# WILD TURKEY
# WOOD DUCK
# YELLOW BREASTED CHAT
# RED CROSSBILL
